# %% [markdown]
# ### Ensemblessss

# %% [markdown]
# Сначала обновим и установим необходимые модули.

# %%
# !pip install --upgrade pip
# !pip install imutils
# !pip install opencv-python
# !pip install --upgrade scikit-learn==0.23.0
# Out:
# Requirement already up-to-date: pip in /home/toharhymes/anaconda3/lib/python3.7/site-packages (20.1.1)
# Requirement already satisfied: imutils in /home/toharhymes/anaconda3/lib/python3.7/site-packages (0.5.3)
# Requirement already satisfied: opencv-python in /home/toharhymes/anaconda3/lib/python3.7/site-packages (4.2.0.34)
# Requirement already satisfied: numpy>=1.14.5 in /home/toharhymes/anaconda3/lib/python3.7/site-packages (from opencv-python) (1.18.1)
# Requirement already up-to-date: scikit-learn==0.23.0 in /home/toharhymes/anaconda3/lib/python3.7/site-packages (0.23.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/toharhymes/anaconda3/lib/python3.7/site-packages (from scikit-learn==0.23.0) (2.1.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /home/toharhymes/anaconda3/lib/python3.7/site-packages (from scikit-learn==0.23.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/toharhymes/anaconda3/lib/python3.7/site-packages (from scikit-learn==0.23.0) (0.14.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /home/toharhymes/anaconda3/lib/python3.7/site-packages (from scikit-learn==0.23.0) (1.18.1)

# %% [markdown]
# Подключение базовых библиотек для обработки изображений

# %%
from IPython.display import Image
from imutils import paths
import numpy as np
import cv2
import os

# %% [markdown]
# Для работы с изображениями, найдем их гистограммы — характеристики распределения интенсивности изображения. Для этого можно воспользоваться следующим методом.

# %%
def extract_histogram(image, bins=(8, 8, 8)):
    hist = cv2.calcHist([image], [0, 1, 2], None, bins, [0, 256, 0, 256, 0, 256])
    cv2.normalize(hist, hist)
    return hist.flatten()

# %% [markdown]
# Считаем изображения из корневой папки train и вычислим гистограмму каждого изображения. Кроме того, отделим метку каждого изображения. Обработка большого числа изображений в облачных сервисах занимает длительное время (1-5 минут).

# %%
imagePaths = sorted(list(paths.list_images('data/train')))
trainData = []
labels = []

for (i, imagePath) in enumerate(imagePaths):
    image = cv2.imread(imagePath, 1)
    label = imagePath.split(os.path.sep)[-1].split(".")[0]
    hist = extract_histogram(image)
    trainData.append(hist)
    labels.append(label)

# %% [markdown]
# Преобразуем метки в удобный формат 0 и 1. Cat заменяем на 1, Dog на 0.

# %%
Y = [1 if x == 'cat' else 0 for x in labels]

# %%
print(Y[0])
Image(filename=imagePaths[0])
# Out:
# 1

# %% [markdown]
# Видно, что классом 1 у нас занумерованы коты (кошки).

# %% [markdown]
# Обучаем первый базовый классификатор - бэггинг деревьев принятия решений

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion='entropy', #критерий разделения
                              min_samples_leaf=10, #минимальное число объектов в листе
                              max_leaf_nodes=20, #максимальное число листьев
                              random_state=220)
bagging = BaggingClassifier(tree, #базовый алгоритм
                            n_estimators=19, #количество деревьев
                            random_state=220)
bagging.fit(trainData, Y)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                         max_leaf_nodes=20,
#                                                         min_samples_leaf=10,
#                                                         random_state=220),
#                   n_estimators=19, random_state=220)

# %% [markdown]
# Теперь обучим модель почти-разделяющий гиперплосоксти.

# %%
from sklearn.svm import LinearSVC

svm = LinearSVC(random_state = 220, C = 1.74)
svm.fit(trainData, Y)
# Out:
# LinearSVC(C=1.74, random_state=220)

# %% [markdown]
# И наконец обучаем третий базовый алгоритм — случайный лес

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=19, #количество деревьев
                             criterion='entropy', #критерий разделения
                              min_samples_leaf=10, #минимальное число объектов в листе
                              max_leaf_nodes=20, #максимальное число листьев
                              random_state=220)
forest.fit(trainData, Y)
# Out:
# RandomForestClassifier(criterion='entropy', max_leaf_nodes=20,
#                        min_samples_leaf=10, n_estimators=19, random_state=220)

# %% [markdown]
# Задаем в качестве решающего метаалгоритма логистическую регрессию:

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='lbfgs', random_state=220)

# %% [markdown]
# Обучаем метаалгоритм

# %%
from sklearn.ensemble import StackingClassifier

base_estimators = [('SVM', svm), ('Bagging DT', bagging), ('DecisionForest', forest)]
sclf = StackingClassifier(estimators=base_estimators, final_estimator=lr, cv=2)
sclf.fit(trainData, Y)
# Out:
# StackingClassifier(cv=2,
#                    estimators=[('SVM', LinearSVC(C=1.74, random_state=220)),
#                                ('Bagging DT',
#                                 BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                                                         max_leaf_nodes=20,
#                                                                                         min_samples_leaf=10,
#                                                                                         random_state=220),
#                                                   n_estimators=19,
#                                                   random_state=220)),
#                                ('DecisionForest',
#                                 RandomForestClassifier(criterion='entropy',
#                                                        max_leaf_nodes=20,
#                                                        min_samples_leaf=10,
#                                                        n_estimators=19,
#                                                        random_state=220))],
#                    final_estimator=LogisticRegression(random_state=220))

# %% [markdown]
# Оценка метамодели. Доля правильной классификации (Accuracy):

# %%
sclf.score(trainData, Y)
# Out:
# 0.851

# %% [markdown]
# Вычислим предсказания для объекта из папки test

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def predict(path):
    singleImage = cv2.imread(path)
    histt = extract_histogram(singleImage)
    histt2 = histt.reshape(1, -1)
    prediction = sclf.predict(histt2)
#     Image(filename=path)
    img = mpimg.imread(path)
    imgplot = plt.imshow(img)
    plt.show()
    print(prediction)
    print(f'Dog {np.round(sclf.predict_proba(histt2)[0][0], 3)}')
    print(f'Cat {np.round(sclf.predict_proba(histt2)[0][1], 3)}')

# %%
predict('data/test/cat.1009.jpg')
# Out:
# [0]
# Dog 0.526
# Cat 0.474

# %%
predict('data/test/cat.1015.jpg')
# Out:
# [1]
# Dog 0.321
# Cat 0.679

# %%
predict('data/test/dog.1014.jpg')
# Out:
# [1]
# Dog 0.324
# Cat 0.676

# %%
predict('data/test/cat.1028.jpg')
# Out:
# [0]
# Dog 0.515
# Cat 0.485

# %% [markdown]
# Видно, что построенный классификатор успешно справился с заданием.
